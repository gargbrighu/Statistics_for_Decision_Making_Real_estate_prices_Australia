# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
from scipy.stats import binom

# %%
pd.set_option('display.max_columns', None)
df = pd.read_csv("D:\Hero vired\Hypothesis\property.csv")
df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0  3/12/2016       2.5    3067.0       2.0       1.0  1.0     202.0
# 1  4/02/2016       2.5    3067.0       2.0       1.0  0.0     156.0
# 2  4/03/2017       2.5    3067.0       3.0       2.0  0.0     134.0
# 3  4/03/2017       2.5    3067.0       3.0       2.0  1.0      94.0
# 4  4/06/2016       2.5    3067.0       3.0       1.0  2.0     120.0
#
#    BuildingArea  YearBuilt CouncilArea  Lattitude  Longtitude  \
# 0           NaN        NaN       Yarra   -37.7996    144.9984
# ...

# %%
df_altona = df[df['Suburb'] == 'Altona']
df_altona
# Out:
#        Suburb          Address  Rooms Type      Price Method        SellerG  \
# 141    Altona     158 Queen St      3    h   520000.0     VB           Greg
# 142    Altona    59 Bracken Gr      5    h  1525000.0      S           Greg
# 143    Altona   1/123 Blyth St      2    t   720000.0      S  hockingstuart
# 144    Altona       4 Blyth St      3    h  1120000.0      S         Barlow
# 145    Altona     20 Linnet St      4    h   780000.0     PI        Sweeney
# ...       ...              ...    ...  ...        ...    ...            ...
# 12216  Altona    86 Grieve Pde      3    h   913000.0      S           Greg
# 12432  Altona  7/35 Grieve Pde      2    u   458000.0     SP  hockingstuart
# 12634  Altona      6 Myrtle Gr      3    h  1248500.0      S             RT
# 13338  Altona       20 Burt St      3    h   920000.0     VB            PRD
# 13339  Altona    1/76 Queen St      2    u   801250.0      S        Sweeney
#
# ...

# %%
df_altona_typical = df_altona[df['Type'] == 't']
df_altona_typical
# Out:
# C:\Users\pusha\AppData\Local\Temp\ipykernel_7616\664247674.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_altona_typical = df_altona[df['Type'] == 't']
#        Suburb            Address  Rooms Type     Price Method        SellerG  \
# 143    Altona     1/123 Blyth St      2    t  720000.0      S  hockingstuart
# 153    Altona     1/265 Queen St      3    t  800000.0     SP  hockingstuart
# 158    Altona      1A Merritt Ct      3    t  705000.0      S  hockingstuart
# 162    Altona     1/152 Blyth St      3    t  743000.0     SP        Gunn&Co
# 173    Altona        12 Spear Ct      3    t  605100.0      S  hockingstuart
# 8568   Altona     2/214 Queen St      2    t  600000.0     SP  hockingstuart
# 8569   Altona      3/8 Rayner St      2    t  597500.0      S  hockingstuart
# 9398   Altona      1/20 Mulga St      3    t  765000.0      S       Williams
# 11266  Altona      65 Sargood St      3    t  815000.0      S  hockingstuart
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  float64
#  10  Bedroom2       13580 non-null  float64
#  11  Bathroom       13580 non-null  float64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   7130 non-null   float64
#  15  YearBuilt      8205 non-null   float64
#  16  CouncilArea    12211 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
df1 = df[['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
       'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
       'Landsize', 'Lattitude',
       'Longtitude', 'Regionname', 'Propertycount']]
df1.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0  3/12/2016       2.5    3067.0       2.0       1.0  1.0     202.0
# 1  4/02/2016       2.5    3067.0       2.0       1.0  0.0     156.0
# 2  4/03/2017       2.5    3067.0       3.0       2.0  0.0     134.0
# 3  4/03/2017       2.5    3067.0       3.0       2.0  1.0      94.0
# 4  4/06/2016       2.5    3067.0       3.0       1.0  2.0     120.0
#
#    Lattitude  Longtitude             Regionname  Propertycount
# 0   -37.7996    144.9984  Northern Metropolitan         4019.0
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  float64
#  10  Bedroom2       13580 non-null  float64
#  11  Bathroom       13580 non-null  float64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  float64
#  14  Lattitude      13580 non-null  float64
#  15  Longtitude     13580 non-null  float64
#  16  Regionname     13580 non-null  object
# ...

# %%
import datetime as dt
df1['Date'] = df1['Date'].apply(pd.to_datetime)
# df1['Date'] = pd.to_datetime(df1['Date'])
df1['Date'] = pd.to_datetime(df1['Date'], format = '%m/%d/%Y')
#df1['Date'] = pd.to_datetime(df1['Date'], format='%m/%d/%Y')
# Out:
# C:\Users\pusha\AppData\Local\Temp\ipykernel_7616\909402944.py:2: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df1['Date'] = df1['Date'].apply(pd.to_datetime)
# C:\Users\pusha\AppData\Local\Temp\ipykernel_7616\909402944.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Date'] = df1['Date'].apply(pd.to_datetime)
# C:\Users\pusha\AppData\Local\Temp\ipykernel_7616\909402944.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  datetime64[ns]
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  float64
#  10  Bedroom2       13580 non-null  float64
#  11  Bathroom       13580 non-null  float64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  float64
#  14  Lattitude      13580 non-null  float64
#  15  Longtitude     13580 non-null  float64
#  16  Regionname     13580 non-null  object
# ...

# %% [markdown]
# Ques 3) For the suburb Abbotsford, what is the probability that out of 10 properties sold, 3 will not have car parking?
# Use the column car in the dataset.Round off your answer to 3 decimal places.

# %%
df_Abbotsford = df1[df1['Suburb'] == 'Abbotsford']
df_Abbotsford.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0 2016-03-12       2.5    3067.0       2.0       1.0  1.0     202.0
# 1 2016-04-02       2.5    3067.0       2.0       1.0  0.0     156.0
# 2 2017-04-03       2.5    3067.0       3.0       2.0  0.0     134.0
# 3 2017-04-03       2.5    3067.0       3.0       2.0  1.0      94.0
# 4 2016-04-06       2.5    3067.0       3.0       1.0  2.0     120.0
#
#    Lattitude  Longtitude             Regionname  Propertycount
# 0   -37.7996    144.9984  Northern Metropolitan         4019.0
# ...

# %% [markdown]
# Total No. of Abbotsford Properties

# %%
Total_no_properties = len(df_Abbotsford)
Total_no_properties
# Out:
# 56

# %% [markdown]
# No. of No Parking Properties

# %%
no_parking = len(df_Abbotsford[df_Abbotsford['Car'] == 0])
no_parking
# Out:
# 15

# %% [markdown]
# Probability of having no Car Parking

# %%
prob_no_parking = no_parking/Total_no_properties
prob_no_parking
# Out:
# 0.26785714285714285

# %% [markdown]
# Calculate probability of 3 out of 10 having no car parking

# %%
n = 10 # Total properties sold
k = 3 # property withour car parking
pmf=binom.pmf(k, n, prob_no_parking)
pmf
# Out:
# 0.2600529293316224

# %% [markdown]
# Round of to 3 decimal places

# %%
prob_round3 = round(pmf,3)
prob_round3
# Out:
# 0.26

# %% [markdown]
# Ques 4)  In the suburb Abbotsford, what are the chances of finding a property with 3 rooms?
# Round your answer to 3 decimal places.

# %%
rooms_3 = len(df_Abbotsford[df_Abbotsford['Rooms'] == 3])
rooms_3
# Out:
# 20

# %%
prob_3rooms = rooms_3/Total_no_properties
prob_3rooms
# Out:
# 0.35714285714285715

# %% [markdown]
# Round of to 3 decimal places

# %%
p_round_3rooms = round(prob_3rooms,3)
p_round_3rooms
# Out:
# 0.357

# %% [markdown]
# Ques 5) In the suburb Abbotsford, what are the chances of finding a property with 2 bathrooms?
# Round your answer to 3 decimal places.

# %%
bathroom_2 = len(df_Abbotsford[df_Abbotsford['Bathroom'] == 2])
bathroom_2
# Out:
# 19

# %%
prob_2bathroom = bathroom_2/Total_no_properties
prob_2bathroom
# Out:
# 0.3392857142857143

# %% [markdown]
# Round of to 3 decimal places

# %%
p_round_2bathroom = round(prob_2bathroom,3)
p_round_2bathroom
# Out:
# 0.339
